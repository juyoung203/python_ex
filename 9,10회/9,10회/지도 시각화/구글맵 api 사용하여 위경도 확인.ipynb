# %% [markdown]
# [Google Maps API](https://developers.google.com/maps/?hl=ko)
#
# Google Maps Geocoding API 신청하여 Key 받기

# %% [markdown]
# ## googlemaps 패키지 설치
# - pip install googlemaps
# - conda install googlemaps

# %% [markdown]
# [공공데이터](https://www.data.go.kr/search/index.do)
# 서울시 5대 범죄 데이터 다운로드
# 공공데이터 포털 한글 인코딩 : euc-kr

# %%
import numpy as np
import pandas as pd

# %%
crime_anal_police = pd.read_csv('./data/02. crime_in_Seoul.csv', 
                                encoding='euc-kr')
crime_anal_police.head()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생 절도 검거  폭력 발생  폭력 검거
# 0   중부서      2      2      3      2    105     65  1,395   477  1,355  1,170
# 1   종로서      3      3      6      5    115     98  1,070   413  1,278  1,070
# 2  남대문서      1      0      6      4     65     46  1,153   382    869    794
# 3  서대문서      2      2      5      4    154    124  1,812   738  2,056  1,711
# 4   혜화서      3      2      5      4     96     63  1,114   424  1,015    861

# %%
crime_anal_police.head()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생 절도 검거  폭력 발생  폭력 검거
# 0   중부서      2      2      3      2    105     65  1,395   477  1,355  1,170
# 1   종로서      3      3      6      5    115     98  1,070   413  1,278  1,070
# 2  남대문서      1      0      6      4     65     46  1,153   382    869    794
# 3  서대문서      2      2      5      4    154    124  1,812   738  2,056  1,711
# 4   혜화서      3      2      5      4     96     63  1,114   424  1,015    861

# %%
import googlemaps

# %%
# api key 등록 사용합니다.
gmaps_key = "AIzaSyCuToLcFEXsgAd37RSpJANLQvLdqMuwSTs" 
gmaps = googlemaps.Client(key=gmaps_key)

# %%
gmaps.geocode('한국경제신문',language='ko')
# Out:
# [{'address_components': [{'long_name': '교동',
#     'short_name': '교동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '속초시',
#     'short_name': '속초시',
#     'types': ['locality', 'political']},
#    {'long_name': '강원도',
#     'short_name': '강원도',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '217-060',
#     'short_name': '217-060',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 강원도 속초시 교동',
#   'geometry': {'location': {'lat': 38.2010973, 'lng': 128.5750644},
#    'location_type': 'GEOMETRIC_CENTER',
#    'viewport': {'northeast': {'lat': 38.2024462802915,
#      'lng': 128.5764133802915},
#     'southwest': {'lat': 38.1997483197085, 'lng': 128.5737154197085}}},
#   'place_id': 'ChIJweMo8Hq82F8RPCUFE3OMdtY',
#   'types': ['establishment', 'point_of_interest']}]

# %%
gmaps.geocode('서울중부경찰서', language='ko')
# Out:
# [{'address_components': [{'long_name': '27',
#     'short_name': '27',
#     'types': ['political', 'premise']},
#    {'long_name': '수표로',
#     'short_name': '수표로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '을지로동',
#     'short_name': '을지로동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '중구',
#     'short_name': '중구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '100-032',
#     'short_name': '100-032',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 중구 을지로동 수표로 27',
#   'geometry': {'location': {'lat': 37.5636465, 'lng': 126.9895796},
#    'location_type': 'ROOFTOP',
# ...

# %%
gmaps.geocode('숙명여자대학교', language='ko')
# Out:
# [{'address_components': [{'long_name': '100',
#     'short_name': '100',
#     'types': ['premise']},
#    {'long_name': '청파로47길',
#     'short_name': '청파로47길',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '청파동',
#     'short_name': '청파동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '용산구',
#     'short_name': '용산구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '140-132',
#     'short_name': '140-132',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 용산구 청파동 청파로47길 100',
#   'geometry': {'location': {'lat': 37.5463899, 'lng': 126.9647134},
#    'location_type': 'ROOFTOP',
# ...

# %%
# 각 관서명 리스트 생성

# 빈 리스트 생성
station_name = []

# 
for name in crime_anal_police['관서명']:
    station_name.append('서울' + str(name[:-1]) + '경찰서')

station_name
# Out:
# ['서울중부경찰서',
#  '서울종로경찰서',
#  '서울남대문경찰서',
#  '서울서대문경찰서',
#  '서울혜화경찰서',
#  '서울용산경찰서',
#  '서울성북경찰서',
#  '서울동대문경찰서',
#  '서울마포경찰서',
#  '서울영등포경찰서',
#  '서울성동경찰서',
#  '서울동작경찰서',
#  '서울광진경찰서',
#  '서울서부경찰서',
#  '서울강북경찰서',
#  '서울금천경찰서',
#  '서울중랑경찰서',
#  '서울강남경찰서',
#  '서울관악경찰서',
#  '서울강서경찰서',
#  '서울강동경찰서',
#  '서울종암경찰서',
#  '서울구로경찰서',
#  '서울서초경찰서',
#  '서울양천경찰서',
#  '서울송파경찰서',
#  '서울노원경찰서',
#  '서울방배경찰서',
#  '서울은평경찰서',
#  '서울도봉경찰서',
#  '서울수서경찰서']

# %%
tmp = gmaps.geocode('서울구로경찰서',language='ko')
tmp
# Out:
# [{'address_components': [{'long_name': '가마산로',
#     'short_name': '가마산로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '구로구',
#     'short_name': '구로구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['locality', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']}],
#   'formatted_address': '대한민국 서울특별시 구로구 가마산로 235',
#   'geometry': {'location': {'lat': 37.494931, 'lng': 126.886731},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.4962799802915,
#      'lng': 126.8880799802915},
#     'southwest': {'lat': 37.49358201970851, 'lng': 126.8853820197085}}},
#   'place_id': 'ChIJmRBVTBSefDURMQeUuNnWXlU',
#   'types': ['establishment', 'point_of_interest', 'police']}]

# %%
tmp[0].get('formatted_address')
# Out:
# '대한민국 서울특별시 구로구 가마산로 235'

# %%
tmp[0].get('geometry')['location']['lat']
# Out:
# 37.494931

# %%
station_addreess = []
station_lat = []
station_lng = []

for name in station_name:
    tmp = gmaps.geocode(name, language='ko')
    station_addreess.append(tmp[0].get("formatted_address"))
    
    tmp_loc = tmp[0].get("geometry")

    station_lat.append(tmp_loc['location']['lat'])
    station_lng.append(tmp_loc['location']['lng'])
    
    print(name + '-->' + tmp[0].get("formatted_address"))
# Out:
# 서울중부경찰서-->대한민국 서울특별시 중구 을지로동 수표로 27
# 서울종로경찰서-->대한민국 서울특별시 종로구 종로1.2.3.4가동 율곡로 46
# 서울남대문경찰서-->대한민국 서울특별시 중구 남대문로5가 한강대로 410
# 서울서대문경찰서-->대한민국 서울특별시 서대문구 미근동 통일로 113
# 서울혜화경찰서-->대한민국 서울특별시 종로구 종로1.2.3.4가동 창경궁로 112-16
# 서울용산경찰서-->대한민국 서울특별시 용산구 원효로1가 12-12
# 서울성북경찰서-->대한민국 서울특별시 성북구 삼선동5가 301
# 서울동대문경찰서-->대한민국 서울특별시 동대문구 청량리동 약령시로21길 29
# 서울마포경찰서-->대한민국 서울특별시 마포구 아현동 618-1
# 서울영등포경찰서-->대한민국 서울특별시 영등포구 당산동3가 2-11
# 서울성동경찰서-->대한민국 서울특별시 성동구 행당동 192-8
# 서울동작경찰서-->대한민국 서울특별시 동작구 노량진동 72
# 서울광진경찰서-->대한민국 서울특별시 광진구 구의1동 자양로 167
# 서울서부경찰서-->대한민국 서울특별시 은평구 대조동 통일로 757
# 서울강북경찰서-->대한민국 서울특별시 강북구 번1동 415-15
# 서울금천경찰서-->대한민국 서울특별시 관악구 신림동 544
# 서울중랑경찰서-->대한민국 서울특별시 중랑구 신내1동 신내역로3길 40-10
# 서울강남경찰서-->대한민국 서울특별시 강남구 대치동 998
# 서울관악경찰서-->대한민국 서울특별시 관악구 봉천동
# 서울강서경찰서-->대한민국 서울특별시 양천구 신월동 화곡로 73
# 서울강동경찰서-->대한민국 서울특별시 강동구 성내1동 성내로 57
# 서울종암경찰서-->대한민국 서울특별시 성북구 종암동 3-1260
# 서울구로경찰서-->대한민국 서울특별시 구로구 가마산로 235
# 서울서초경찰서-->대한민국 서울특별시 서초구 서초3동 반포대로 179
# 서울양천경찰서-->대한민국 서울특별시 양천구 신정6동 목동동로 99
# ...

# %%
station_lat
# Out:
# [37.5636465,
#  37.5755578,
#  37.5547584,
#  37.5647848,
#  37.5718401,
#  37.5411211,
#  37.5897271,
#  37.58506149999999,
#  37.550814,
#  37.5257884,
#  37.5617309,
#  37.5130685,
#  37.542873,
#  37.6128611,
#  37.6373881,
#  37.4814051,
#  37.618692,
#  37.5094352,
#  37.4743789,
#  37.5397827,
#  37.528511,
#  37.6020592,
#  37.494931,
#  37.4956054,
#  37.5165667,
#  37.5019065,
#  37.6423605,
#  37.4815453,
#  37.6283597,
#  37.6533589,
#  37.49349]

# %%
station_lng
# Out:
# [126.9895796,
#  126.9848674,
#  126.9734981,
#  126.9667762,
#  126.9988562,
#  126.9676935,
#  127.0161318,
#  127.0457679,
#  126.954028,
#  126.901006,
#  127.0363806,
#  126.9428078,
#  127.083821,
#  126.9274951,
#  127.0273238,
#  126.9099508,
#  127.1047136,
#  127.0669578,
#  126.9509748,
#  126.8299968,
#  127.1268224,
#  127.0321577,
#  126.886731,
#  127.0052504,
#  126.8656763,
#  127.1271513,
#  127.0714027,
#  126.9829992,
#  126.9287226,
#  127.052682,
#  127.0772119]

# %%
crime_anal_police['위도']=station_lat

# %%
crime_anal_police['경도']=station_lng

# %%
crime_anal_police
# Out:
#      관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  \
# 0    중부서      2      2      3      2    105     65  1,395    477  1,355
# 1    종로서      3      3      6      5    115     98  1,070    413  1,278
# 2   남대문서      1      0      6      4     65     46  1,153    382    869
# 3   서대문서      2      2      5      4    154    124  1,812    738  2,056
# 4    혜화서      3      2      5      4     96     63  1,114    424  1,015
# 5    용산서      5      5     14     14    194    173  1,557    587  2,050
# 6    성북서      2      2      2      1     86     71    953    409  1,194
# 7   동대문서      5      5     13     13    173    146  1,981    814  2,548
# 8    마포서      8      8     14     10    294    247  2,555    813  2,983
# 9   영등포서     14     12     22     20    295    183  2,964    978  3,572
# 10   성동서      4      4      9      8    126    119  1,607    597  1,612
# 11   동작서      5      5      9      5    285    139  1,865    661  1,910
# ...

# %%
crime_anal_police['관서명']=station_name

# %%
crime_anal_police
# Out:
#          관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  \
# 0    서울중부경찰서      2      2      3      2    105     65  1,395    477  1,355
# 1    서울종로경찰서      3      3      6      5    115     98  1,070    413  1,278
# 2   서울남대문경찰서      1      0      6      4     65     46  1,153    382    869
# 3   서울서대문경찰서      2      2      5      4    154    124  1,812    738  2,056
# 4    서울혜화경찰서      3      2      5      4     96     63  1,114    424  1,015
# 5    서울용산경찰서      5      5     14     14    194    173  1,557    587  2,050
# 6    서울성북경찰서      2      2      2      1     86     71    953    409  1,194
# 7   서울동대문경찰서      5      5     13     13    173    146  1,981    814  2,548
# 8    서울마포경찰서      8      8     14     10    294    247  2,555    813  2,983
# 9   서울영등포경찰서     14     12     22     20    295    183  2,964    978  3,572
# 10   서울성동경찰서      4      4      9      8    126    119  1,607    597  1,612
# ...

# %%
data=crime_anal_police.ix[:,(1,5,-2,-1)]

# %%
data
# Out:
#     살인 발생  강간 발생         위도          경도
# 0       2    105  37.563646  126.989580
# 1       3    115  37.575558  126.984867
# 2       1     65  37.554758  126.973498
# 3       2    154  37.564785  126.966776
# 4       3     96  37.571840  126.998856
# 5       5    194  37.541121  126.967693
# 6       2     86  37.589727  127.016132
# 7       5    173  37.585061  127.045768
# 8       8    294  37.550814  126.954028
# 9      14    295  37.525788  126.901006
# 10      4    126  37.561731  127.036381
# 11      5    285  37.513069  126.942808
# 12      4    240  37.542873  127.083821
# 13      2     70  37.612861  126.927495
# 14      7    153  37.637388  127.027324
# 15      3    151  37.481405  126.909951
# 16     13    187  37.618692  127.104714
# 17      3    300  37.509435  127.066958
# 18      9    320  37.474379  126.950975
# 19      7    262  37.539783  126.829997
# 20      4    156  37.528511  127.126822
# 21      3     64  37.602059  127.032158
# ...

# %%
crime_anal_police.to_csv('./위치.csv')

# %%
a = np.array(data)

# %%
a
# Out:
# array([[   2.       ,  105.       ,   37.5636465,  126.9895796],
#        [   3.       ,  115.       ,   37.5755578,  126.9848674],
#        [   1.       ,   65.       ,   37.5547584,  126.9734981],
#        [   2.       ,  154.       ,   37.5647848,  126.9667762],
#        [   3.       ,   96.       ,   37.5718401,  126.9988562],
#        [   5.       ,  194.       ,   37.5411211,  126.9676935],
#        [   2.       ,   86.       ,   37.5897271,  127.0161318],
#        [   5.       ,  173.       ,   37.5850615,  127.0457679],
#        [   8.       ,  294.       ,   37.550814 ,  126.954028 ],
#        [  14.       ,  295.       ,   37.5257884,  126.901006 ],
#        [   4.       ,  126.       ,   37.5617309,  127.0363806],
#        [   5.       ,  285.       ,   37.5130685,  126.9428078],
#        [   4.       ,  240.       ,   37.542873 ,  127.083821 ],
#        [   2.       ,   70.       ,   37.6128611,  126.9274951],
# ...

# %%
police_mark = folium.Map(location=(37.563646, 126.989586))

for 관서명, 강간발생, i,j in a:
    folium.Marker(location = [i,j], popup = 'Police Station').add_to(ploice_mark)
    
    folium.CircleMarker([i, j], radius = 강간발생,
                       pipup='범위지정', color = '#3186cc',
                       fill=True, fill_color=('#ff0000')).add_to(police_mark)
police_mark
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-2b486dfa45bf> in <module>()
#       2
#       3 for 관서명, 강간발생, i,j in a:
# ----> 4     folium.Marker(location = [i,j], popup = 'Police Station').add_to(ploice_mark)
#       5
#       6     folium.CircleMarker([i, j], radius = 강간발생,
#
# NameError: name 'ploice_mark' is not defined

# %%
import json
import folium

# 구 별 인구수 데이터 로드
popDF = pd.read_csv('./kr_data/pop_kor.csv', encoding='UTF-8')#, index_col='구별')

# 위치 데이터 json 파일 로드
geo_path = './kr_data/skorea_municipalities_geo.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

# %%
popDF
# Out:
#       구별     인구수
# 0    강남구  581760
# 1    강동구  463321
# 2    강북구  334426
# 3    강서구  595691
# 4    관악구  529031
# 5    광진구  375180
# 6    구로구  454604
# 7    금천구  256167
# 8    노원구  578221
# 9    도봉구  353241
# 10  동대문구  373824
# 11   동작구  412774
# 12   마포구  398351
# 13  서대문구  323105
# 14   서초구  451258
# 15   성동구  305065
# 16   성북구  469560
# 17   송파구  667480
# 18   양천구  489010
# 19  영등포구  417811
# 20   용산구  247909
# 21   은평구  502578
# 22   종로구  163822
# 23    중구  134329
# 24   중랑구  418620

# %%
sub = gmaps.geocode('서초구',language='ko')
sub
# Out:
# [{'address_components': [{'long_name': '서초구',
#     'short_name': '서초구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']}],
#   'formatted_address': '대한민국 서울특별시 서초구',
#   'geometry': {'bounds': {'northeast': {'lat': 37.5260893, 'lng': 127.0948845},
#     'southwest': {'lat': 37.4259627, 'lng': 126.9795194}},
#    'location': {'lat': 37.4837121, 'lng': 127.0324112},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 37.5260893, 'lng': 127.0948845},
#     'southwest': {'lat': 37.4259627, 'lng': 126.9795194}}},
#   'place_id': 'ChIJ0ay8ZjShfDURq_YqSP_HC7c',
#   'types': ['political', 'sublocality', 'sublocality_level_1']}]

# %%
sub[0]['geometry']['bounds']['northeast']['lat']
# Out:
# 37.5260893

# %%
geo_str =r'./kr_data/skorea_municipalities_geo.json'

# %%
p =folium.Map([37, 126], zoom_start=3)

m.choropleth(geo_data=geo_str, data=popDF,
            columns =['구별','인구수'], key_on='feature.id',
            fill_color = 'BuPu', fill_opacity=0.7, line_opacity=0.2,
            legend_name = '인구수')

# %%
for 구별, 인구수, i,j in p:
    folium.Marker(location = [i,j], popup = 'Police Station').add_to(p)
    
    folium.CircleMarker([i, j], radius = 강간발생*0.01,
                       pipup='범위지정', color = '#3186cc',
                       fill=True, fill_color=('#ff0000')).add_to(p)
p
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-110-de4879731c4d> in <module>()
# ----> 1 for 구별, 인구수, i,j in p:
#       2     folium.Marker(location = [i,j], popup = 'Police Station').add_to(p)
#       3
#       4     folium.CircleMarker([i, j], radius = 강간발생*0.01,
#       5                        pipup='범위지정', color = '#3186cc',
#
# TypeError: 'Map' object is not iterable

# %% [markdown]
# #범죄마커표시`

# %%
import pandas as pd
import numpy as np
import folium

# %%
data = pd.read_csv("./data/02. crime_in_Seoul.csv", encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-84-46b8619ccd4e> in <module>()
# ----> 1 data = pd.read_csv("./data/02. crime_in_Seoul.csv", encoding='utf-8')
#
# ...
