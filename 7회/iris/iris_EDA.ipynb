# %% [markdown]
# # Iris Data EDA(Exploratory data analysis)

# %% [markdown]
# ## 목차
# 1. [문제정의](#1)
#     1. 목표
# 2. [데이터 수집 및 소개](#2)
#     1. 수집
#     2. 소개
# 3. [데이터 전처리](#3)
# 4. [탐색적 데이터 분석](#4)

# %% [markdown]
# <a id= '1' ></a>
# ## 1. 문제정의

# %% [markdown]
# **목표 **
# 종류가 다른 3가지 붓꽃(setosa, versicolor, virginica) 꽃받침, 꽃잎의 길이에 따라 구분할 수 있을까?
#
# ---

# %% [markdown]
# <a id='2'></a>
#
# ## 2. 데이터 수집 및 소개

# %% [markdown]
# **수집**
#     - 연구용으로 공개된 자료이다. 자세한 사항은 아래 링크를 참조하자.
#     - 작성자 : RA Fisher
#     - 기부자 : Michael Marshall (MARSHALL % PLU '@' io.arc.nasa.gov )
#     - 출처 :  https://archive.ics.uci.edu/ml/datasets/Iris

# %% [markdown]
# **소개**
#
# 속성정보
#
# 1. sepal length in cm (꽃받침 길이)
# 2. sepal width in cm  (꽃받침 너비)
# 3. petal length in cm (꽃잎 길이)
# 4. petal width in cm  (꽃잎 너비)
# 5. class:
# -- Iris Setosa
# -- Iris Versicolour
# -- Iris Virginica
#
# ---

# %% [markdown]
# <a id='3'></a>
# ## 3. 데이터 전처리

# %% [markdown]
# ### import 패키지

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
# sns.set(style="white", color_codes=True)

# %% [markdown]
# ### 데이터 로드

# %%
iris = pd.read_csv("./input/Iris.csv") # pa.read_csv로 파일 읽어오기 , header 존재

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# 데이터별 요약통계량을 살펴 보자.
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# 각 종 별 개수 50개 동일
iris["Species"].value_counts()
# Out:
# Iris-versicolor    50
# Iris-setosa        50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# 데이터의 결측치 존재하지 않다. 매우 깔끔한 데이터인 것을 확인할 수 있다.

# %% [markdown]
# 실제 업무 데이터와 연구용 데이터는 많은 차이가 있다.
# 이렇게 깔끔하게 정리된 데이터는 찾아보기 어려우며.. 분석 업무의 1/3 이상 데이터 전처리에 사용한다.

# %% [markdown]
# <a id='4'></a>
# ## 4. 탐색적 데이터 분석

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %%
plt.scatter(iris['SepalLengthCm'],iris['SepalWidthCm'])

# %%
# 꽃받침 길이,너비 x,y 그래프
iris.plot(kind="scatter", x="SepalLengthCm", y="SepalWidthCm")

# %%
sns.jointplot(x="PetalLengthCm", y="PetalwidthCm", data=iris, size=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-d306e5cedd3a> in <module>()
# ----> 1 sns.jointplot(x="PetalLengthCm", y="PetalwidthCm", data=iris, size=3)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2217     grid = JointGrid(x, y, data, dropna=dropna,
#    2218                      size=size, ratio=ratio, space=space,
# -> 2219                      xlim=xlim, ylim=ylim)
#    2220
#    2221     # Plot the data using the grid
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in __init__(self, x, y, data, size, ratio, space, dropna, xlim, ylim)
#    1664             if isinstance(var, string_types):
#    1665                 err = "Could not interpret input '{}'".format(var)
# ...

# %%
# 위와 같은 그래프이지만 데이터 분포까지 확인할 수 있다.
sns.jointplot(x="SepalLengthCm", y="SepalWidthCm", data=iris, size=8)

# %%
sns.FacetGrid(iris, hue="Species", size=10) \
   .map(plt.scatter, "PetalLengthCm", "PetalWidthCm") \
   .add_legend()

# %%
sns.FacetGrid(iris, hue="Species", size=10) \
   .map(plt.scatter, "SepalLengthCm", "SepalWidthCm") \
   .add_legend()

# %%
#종 별 꽃잎 길이 박스플롯 (x축의 변수가 무조건 한개)
sns.boxplot(x="Species", y="PetalLengthCm", data=iris)

# %%
# 두 그래프 합쳐서 보여준다.
ax = sns.boxplot(x="Species", y="PetalLengthCm", data=iris)
ax = sns.stripplot(x="Species", y="PetalLengthCm", data=iris, jitter=True, edgecolor="gray")

# %%
# 바이올린 플롯으로 확인해보자.
sns.violinplot(x="Species", y="PetalLengthCm", data=iris, size=6)

# %%
sns.FacetGrid(iris, hue="Species", size=6).map(sns.kdeplot, "PetalLengthCm").add_legend()

# %%
iris.drop(id,axis=1)

# %%
sns.pairplot(iris.drop("Id", axis=1), hue="Species", size=3) # pairplot는 모든 변수를 2개씩 비교하여 그려줌. hue는 축을 뜻함.

# %%
sns.pairplot(iris.drop("Id", axis=1), hue="Species", size=2, diag_kind="kde")

# %%
iris.drop("Id", axis=1).boxplot(by="Species", figsize=(12, 6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000BC59E997F0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000BC5A0891D0>]], dtype=object)

# %%
iris = pd.read_csv("./input/Iris.csv")

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")
iris = sns.load_dataset("iris")

# "Melt" the dataset to "long-form" or "tidy" representation
iris = pd.melt(iris, "species", var_name="measurement")

# Initialize the figure
f, ax = plt.subplots()
sns.despine(bottom=True, left=True)

# Show each observation with a scatterplot
sns.stripplot(x="value", y="measurement", hue="species",
              data=iris, dodge=True, jitter=True,
              alpha=.25, zorder=1)

# Show the conditional means
sns.pointplot(x="value", y="measurement", hue="species",
              data=iris, dodge=.532, join=False, palette="dark",
              markers="d", scale=.75, ci=None)

# Improve the legend 
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[3:], labels[3:], title="species",
          handletextpad=0, columnspacing=1,
          loc="lower right", ncol=3, frameon=True)

# %%
c = pd.read_csv('./crime_in_Seoul.csv', encoding='euc-kr')

# %%
c.head()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생 절도 검거  폭력 발생  폭력 검거
# 0   중부서      2      2      3      2    105     65  1,395   477  1,355  1,170
# 1   종로서      3      3      6      5    115     98  1,070   413  1,278  1,070
# 2  남대문서      1      0      6      4     65     46  1,153   382    869    794
# 3  서대문서      2      2      5      4    154    124  1,812   738  2,056  1,711
# 4   혜화서      3      2      5      4     96     63  1,114   424  1,015    861

# %%
# 한글 폰트
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")
crime_in_Seoul = sns.load_dataset("crime_in_Seoul.csv")

# "Melt" the dataset to "long-form" or "tidy" representation
crime_in_Seoul = pd.melt(crime_in_Seoul, "관서명", var_name="measurement")

# Initialize the figure
f, ax = plt.subplots()
sns.despine(bottom=True, left=True)

# Show each observation with a scatterplot
sns.stripplot(x="살인 발생", y="살인 검거", hue="species",
              data=iris, dodge=True, jitter=True,
              alpha=.25, zorder=1)

# Show the conditional means
sns.pointplot(x="value", y="measurement", hue="species",
              data=iris, dodge=.532, join=False, palette="dark",
              markers="d", scale=.75, ci=None)

# Improve the legend 
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[3:], labels[3:], title="species",
          handletextpad=0, columnspacing=1,
          loc="lower right", ncol=3, frameon=True)

# %% [markdown]
# ### http://www.color-hex.com/
